# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master('local[1]')\
                    .appName('practice')\
                    .getOrCreate()
sc = spark.sparkContext
print(sc)
print(spark)
print(sc.appName)
# Out:
# <SparkContext master=local[1] appName=practice>
# ...
# practice

# %%
sc.stop()

# %%
spark.stop()
